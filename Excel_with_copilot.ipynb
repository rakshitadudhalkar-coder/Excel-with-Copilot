# %% [markdown]
# #1.Use Copilot to identify and summarize missing values in the dataset.
#
# Ans -
#
# Copilot Prompt -
#
# Identify all missing or blank values in this dataset and summarize them column-wise.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #2.Use Copilot to fill missing values in the Region and Category columns.
#
# Ans -
#
# Copilot Promt - Fill all missing values in the dataset using suitable methods.
#
#
# Numeric columns like Units Sold and Unit Price were filled using average values.

# %% [markdown]
# #3. Fill missing numeric values in the units sold and unit price column.
#
# Ans -
#
# region column -
# Filled missing Region values with:unknown
#
# units sold column-
# =AVERAGE(H:H)
#
# unit price column -
# =AVERAGE(I:I)

# %% [markdown]
# #4.create a new calculated column Total Revenue.
#
# Ans -
#
# Total Revenue Formula
#
# =H2*I2
#
# New Column Name -
#
# Total Revenue

# %% [markdown]
# #5. Use Copilot to find the total price of Order ID = ‘ORD0123’
#
# Ans -
#
# =Units Sold * Unit Price
#
# For ORD0123:
#
# Units Sold = 46
# Unit Price = 344.55
# Total Price
#
# 46×344.55=15849.3

# %% [markdown]
# #6. Use Copilot to generate a summary chart of average profit by region.
#
# Ans -
# Steps
#
# Select dataset
#
# Click Copilot
#
# Enter the prompt
#
# Copilot generates:
#
# Bar Chart
#
# Column Chart
#
# Pivot Charts
#
# Copilot generated a summary chart displaying the average profit across different regions such as East, West, North, and South

# %% [markdown]
# #7.Create a pivot table summarizing total sales by category and region.
#
# Ans -
#
# Steps
# Select dataset
# Insert → Pivot Table
# Configure:
# Rows → Category
# Columns → Region
# Values → Sum of Total Revenue
#
# A pivot table was created to summarize total sales by Category and Region, helping compare regional sales performance across product categories.

# %% [markdown]
# #8. Build a dashboard combining key KPIs and charts.
#
# Ans -
#
# Total Sales
# Total Profit
# Total Orders
# Average Revenue
#
# Charts
# Sales by Region
# Sales by Category
# Profit Trend
# Online vs Offline Sales
#
# Filters/Slicers
# Country
# Region
# Category
# Sales Channel

# %% [markdown]
# #9.Use Copilot to generate a summary report
#
# Ans -
# Generate a business summary report for this sales dataset.
#
# The dataset contains sales transactions across multiple countries and product categories. After cleaning missing values, total revenue and profit metrics were calculated. The analysis showed variations in sales performance across regions and categories. Interactive dashboards and pivot tables were created to visualize sales trends, category performance, and regional profitability. Copilot assisted in automating data cleaning, analysis, and report generation efficiently.
